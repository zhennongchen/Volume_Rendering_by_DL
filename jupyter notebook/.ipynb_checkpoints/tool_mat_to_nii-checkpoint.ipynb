# %%
import numpy as np
import function_list_VR as ff
import os
import scipy.io
import nibabel as nb

# %%
main_path ='/Volumes/Seagate MacOS/predicted_seg/';
patient_list = ff.find_all_target_files(['Abnormal/*'],main_path)
print(patient_list.shape)
# Out:
# (183,)

# %%
for i in range(0,patient_list.shape[0]):
    p = patient_list[i]
    patient_id = os.path.basename(p)
    

    if os.path.isdir(os.path.join(p,'seg-pred-0.625-4classes')) == 1 and os.path.isdir(os.path.join(p,'seg-pred-0.625-4classes-connected-mat')) == 1:
        print(patient_id)
        if os.path.isfile(os.path.join(p,'seg-pred-0.625-4classes-connected-retouch','pred_s_0.nii.gz')):
            print('already done')
            continue
        
        mat_folder = os.path.join(p,'seg-pred-0.625-4classes-connected-mat')
        mat_list = ff.sort_timeframe(ff.find_all_target_files(['*.mat'],mat_folder),1,'_')
        for m in mat_list:
            t = ff.find_timeframe(m,1,'_')
            ##########
            data = scipy.io.loadmat(m) 
            data = data['image']
            ##########
            
            # load corresponding nii file for affine matrix
            seg_file = nb.load(os.path.join(p,'seg-pred-0.625-4classes','pred_s_'+str(t)+'.nii.gz'))
            seg_connected = nb.Nifti1Image(data, seg_file.affine)
            # save
            save_file = os.path.join(p,'seg-pred-0.625-4classes-connected-retouch','pred_s_'+str(t)+'.nii.gz')
            if os.path.isfile(save_file) == 1:
                continue
            else:
                os.makedirs(os.path.dirname(save_file), exist_ok = True)
                nb.save(seg_connected, save_file)
# Out:
# CVC1801161735
# already done
# CVC1802051130
# already done
# CVC1802081042
# already done
# CVC1802161049
# already done
# CVC1802161058
# already done
# CVC1803011106
# already done
# CVC1803131254
# already done
# CVC1804051005
# already done
# CVC1804161050
# already done
# CVC1804271404
# already done
# CVC1805030906
# already done
# CVC1805031013
# already done
# CVC1805291602
# already done
# CVC1806081445
# already done
# CVC1806141302
# already done
# CVC1807171636
# already done
# CVC1809120929
# already done
# CVC1810011258
# already done
# CVC1810121123
# already done
# CVC1810261105
# already done
# CVC1811170855
# already done
# CVC1811191453
# already done
# CVC1811291020
# already done
# CVC1812021159
# already done
# CVC1812101529
# already done
# CVC1812171008
# already done
# CVC1812171335
# already done
# CVC1812211343
# already done
# CVC1812261003
# already done
# CVC1901041107
# already done
# CVC1901171310
# already done
# CVC1901171514
# already done
# CVC1901221024
# already done
# CVC1901232112
# already done
# CVC1901241109
# already done
# CVC1901241202
# already done
# CVC1901241836
# already done
# CVC1901280915
# already done
# CVC1901281219
# already done
# CVC1901281631
# already done
# CVC1901301419
# already done
# CVC1902051046
# already done
# CVC1902081532
# already done
# CVC1902111646
# already done
# CVC1902251312
# already done
# CVC1903130917
# already done
# CVC1903151505
# already done
# CVC1903181837
# already done
# CVC1904011510
# already done
# CVC1904011730
# already done
# CVC1904081524
# already done
# CVC1904091354
# already done
# CVC1904111039
# already done
# CVC1904121404
# already done
# CVC1904220946
# already done
# CVC1904221041
# already done
# CVC1904230903
# already done
# CVC1904261403
# already done
# CVC1904291452
# already done
# CVC1905130912
# already done
# CVC1905152247
# already done
# CVC1905200857
# already done
# CVC1905201422
# already done
# CVC1905281145
# already done
# CVC1905281332
# already done
# CVC1905311311
# already done
# CVC1906051055
# already done
# CVC1906051309
# already done
# CVC1906241353
# already done
# CVC1906241425
# already done
# CVC1906281017
# already done
# CVC1907091404
# already done
# CVC1907101438
# already done
# CVC1907221621
# already done
# CVC1907251518
# already done
# CVC1907261726
# already done
# CVC1907301359
# already done
# CVC1908061347
# already done
# CVC1908151208
# already done
# CVC1908211051
# already done
# CVC1908220904_Kawasaki_70ms
# already done
# CVC1908231346
# already done
# CVC1908280929
# already done
# CVC1908300930
# already done
# CVC1908300959_CRT
# already done
# CVC1908302026
# already done
# CVC1909030903
# already done
# CVC1909171108
# already done
# CVC1909191511_Sept_WMA_dyssynch
# already done
# CVC1909251456_CRT
# already done
# CVC1909271343
# already done
# CVC1909301118
# already done
# CVC1910041633
# already done
# CVC1910071111
# already done
# CVC1910081343
# already done
# CVC1910090949
# already done
# CVC1910150845
# already done
# CVC1910160900
# already done
# CVC1910180859
# already done
# CVC1910181441
# already done
# CVC1910221018
# already done
# CVC1911011117
# already done
# CVC1911081010
# already done
# CVC1911141113
# already done
# CVC1911141358
# already done
# CVC1912060934
# already done
# CVC1912121107
# already done
# CVC1912181517
# already done
# CVC1912300903
# already done
# CVC2001031821
# already done
# CVC2001081016
# already done
# CVC2001081447
# already done
# CVC2001090854
# already done
# CVC2001091140
# already done
# CVC2001131028
# already done
# CVC2001140915
# already done
# CVC2001141429
# already done
# CVC2001151052
# already done
# CVC2001161056
# already done
# CVC2001241336
# already done
# CVC2001280905
# already done
# CVC2001280953
# already done
# CVC2001290958
# already done
# CVC2002061040
# already done
# CVC2002111026
# already done
# CVC2002131112
# already done
# CVC2002280951
# already done
# CVC2003021005
# already done
# CVC2003050954
# already done
# CVC2003061127
# already done
# CVC2003111432
# already done
# CVC2003121139
# already done
# CVC2003191108
# already done
# CVC2003191153
# already done
# CVC2003191457
# already done
# CVC2003231005
# already done
# CVC2004131548
# already done
# CVC2005081609
# already done
# CVC2005141310
# already done
# CVC2005150910
# already done
# CVC2005201013
# already done
# CVC2005281833
# already done
# CVC2005291441
# already done
# CVC2006010933
# already done
# CVC2006021121
# already done
# CVC2006121439
# already done
# CVC2006191006
# already done
# CVC2006230931
# already done
# CVC2006241829
# already done
# CVC2006261457
# already done
